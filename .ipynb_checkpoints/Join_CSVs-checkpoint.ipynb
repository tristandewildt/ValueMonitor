# %%
import sys
import pprint
import os
import pandas as pd
import dateutil.parser

sys.path.append('./code')

# %%
df = pd.read_csv('D:\SURFdrive\Postdoc\ET Lab\Data research transitions\scopus (1).csv')
for i in range(20):
    new_df = pd.read_csv('D:\SURFdrive\Postdoc\ET Lab\Data research transitions\scopus ('+str(i + 2)+').csv')
    df = df.append(new_df)

# %%
df
# Out:
#                                                 Authors  \
# 0     Bannor R.K., Oppong-Kyeremeh H., K. M. Kuwornu J.
# 1     Peña-Miranda D.D., Guevara-Plaza A., Fraiz-Bre...
# 2              Mtapuri O., Camilleri M.A., Dłużewska A.
# 3                               Keles C., Yazicioglu F.
# 4     Schmid N., Beaton C., Kern F., McCulloch N., S...
# ...                                                 ...
# 1013                         [No author name available]
# 1014                         [No author name available]
# 1015                         [No author name available]
# 1016                         [No author name available]
# 1017                         [No author name available]
#
#                                                   Title  Year  \
# 0     Examining the Link between the Theory of Plann...  2021
# 1     Corporate social responsibility model for a co...  2021
# 2     Advancing community-based tourism approaches f...  2021
# ...

# %%
df.to_csv('./data/scopus_energy_social_science.csv',index=False)
